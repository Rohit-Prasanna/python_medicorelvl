# %%
import pandas as pd
import numpy
df= pd .read_csv("dataset.csv")
df
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave   NaN      IR1
# 95  96          60       RL          NaN     9765   Pave   NaN      IR2
# 96  97          20       RL         78.0    10264   Pave   NaN      IR1
# 97  98          20       RL         73.0    10921   Pave   NaN      Reg
# 98  99          30       RL         85.0    10625   Pave   NaN      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
df.isnull().any()
# Out:
# Id              False
# MSSubClass      False
# MSZoning        False
# LotFrontage      True
# LotArea         False
# Street          False
# Alley            True
# LotShape        False
# LandContour     False
# Utilities       False
# LotConfig       False
# LandSlope       False
# Neighborhood    False
# Condition1      False
# Condition2      False
# BldgType        False
# HouseStyle      False
# OverallQual     False
# OverallCond     False
# YearBuilt       False
# YearRemodAdd    False
# RoofStyle       False
# RoofMatl        False
# Exterior1st     False
# Exterior2nd     False
# MasVnrType      False
# MasVnrArea      False
# ExterQual       False
# ExterCond       False
# Foundation      False
# BsmtQual         True
# BsmtCond         True
# BsmtExposure     True
# BsmtFinType1     True
# BsmtFinSF1      False
# BsmtFinType2     True
# dtype: bool

# %%
df.isnull().any().value_counts()
# Out:
# False    29
# True      7
# dtype: int64

# %%
df['BsmtQual'].value_counts()
# Out:
# TA    45
# Gd    37
# Ex    13
# Fa     1
# Name: BsmtQual, dtype: int64

# %%
df['BsmtQual'].isnull().value_counts()
# Out:
# False    96
# True      3
# Name: BsmtQual, dtype: int64

# %%
df['BsmtQual'].fillna("Gd",inplace=True)

# %%
df['BsmtQual'].isnull().value_counts()
# Out:
# False    99
# Name: BsmtQual, dtype: int64

# %%
df
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL         65.0     8450   Pave   NaN      Reg
# 1    2          20       RL         80.0     9600   Pave   NaN      Reg
# 2    3          60       RL         68.0    11250   Pave   NaN      IR1
# 3    4          70       RL         60.0     9550   Pave   NaN      IR1
# 4    5          60       RL         84.0    14260   Pave   NaN      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL         69.0     9337   Pave   NaN      IR1
# 95  96          60       RL          NaN     9765   Pave   NaN      IR2
# 96  97          20       RL         78.0    10264   Pave   NaN      IR1
# 97  98          20       RL         73.0    10921   Pave   NaN      Reg
# 98  99          30       RL         85.0    10625   Pave   NaN      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
df['BsmtCond'].value_counts()
# Out:
# TA    89
# Gd     4
# Fa     3
# Name: BsmtCond, dtype: int64

# %%
df['BsmtCond'].isnull().value_counts()
# Out:
# False    96
# True      3
# Name: BsmtCond, dtype: int64

# %%
df['BsmtCond']=df['BsmtCond'].fillna(int(0))

# %%
df['BsmtCond'].isnull().value_counts()
# Out:
# False    99
# Name: BsmtCond, dtype: int64

# %%
df['BsmtFinType1'].value_counts()
# Out:
# Unf    31
# GLQ    27
# ALQ    18
# Rec     9
# BLQ     8
# LwQ     3
# Name: BsmtFinType1, dtype: int64

# %%
df['BsmtFinType1']=df['BsmtFinType1'].fillna(int(0))

# %%
df['BsmtFinType1'].isnull().value_counts()
# Out:
# False    99
# Name: BsmtFinType1, dtype: int64

# %%
df['BsmtFinType2'].value_counts()
# Out:
# Unf    87
# BLQ     4
# GLQ     2
# ALQ     1
# Rec     1
# LwQ     1
# Name: BsmtFinType2, dtype: int64

# %%
df['BsmtFinType2'].isnull().value_counts()
# Out:
# False    96
# True      3
# Name: BsmtFinType2, dtype: int64

# %%
df['BsmtFinType2']=df['BsmtFinType2'].fillna(int(0))

# %%
df['BsmtFinType2'].isnull().value_counts()
# Out:
# False    99
# Name: BsmtFinType2, dtype: int64

# %%
df['BsmtExposure'].isnull().value_counts()
# Out:
# False    96
# True      3
# Name: BsmtExposure, dtype: int64

# %%
df['BsmtExposure']=df['BsmtExposure'].fillna(df['BsmtExposure'].mode()[0])

# %%
df['BsmtExposure'].isnull().value_counts()
# Out:
# False    99
# Name: BsmtExposure, dtype: int64

# %%
df['LotFrontage'].isnull().value_counts()
# Out:
# False    85
# True     14
# Name: LotFrontage, dtype: int64

# %%
df['LotFrontage'] = df['LotFrontage'].fillna(df['LotFrontage'].mean())

# %%
df
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0    1          60       RL    65.000000     8450   Pave   NaN      Reg
# 1    2          20       RL    80.000000     9600   Pave   NaN      Reg
# 2    3          60       RL    68.000000    11250   Pave   NaN      IR1
# 3    4          70       RL    60.000000     9550   Pave   NaN      IR1
# 4    5          60       RL    84.000000    14260   Pave   NaN      IR1
# ..  ..         ...      ...          ...      ...    ...   ...      ...
# 94  95          60       RL    69.000000     9337   Pave   NaN      IR1
# 95  96          60       RL    71.341176     9765   Pave   NaN      IR2
# 96  97          20       RL    78.000000    10264   Pave   NaN      IR1
# 97  98          20       RL    73.000000    10921   Pave   NaN      Reg
# 98  99          30       RL    85.000000    10625   Pave   NaN      Reg
#
#    LandContour Utilities  ... MasVnrArea ExterQual ExterCond Foundation  \
# ...

# %%
df.drop(['Alley'], axis=1, inplace=True)

# %%
df
# Out:
#     Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour  \
# 0    1          60       RL    65.000000     8450   Pave      Reg         Lvl
# 1    2          20       RL    80.000000     9600   Pave      Reg         Lvl
# 2    3          60       RL    68.000000    11250   Pave      IR1         Lvl
# 3    4          70       RL    60.000000     9550   Pave      IR1         Lvl
# 4    5          60       RL    84.000000    14260   Pave      IR1         Lvl
# ..  ..         ...      ...          ...      ...    ...      ...         ...
# 94  95          60       RL    69.000000     9337   Pave      IR1         Lvl
# 95  96          60       RL    71.341176     9765   Pave      IR2         Lvl
# 96  97          20       RL    78.000000    10264   Pave      IR1         Lvl
# 97  98          20       RL    73.000000    10921   Pave      Reg         HLS
# 98  99          30       RL    85.000000    10625   Pave      Reg         Lvl
#
# ...

# %%
df.isnull().any().value_counts()
# Out:
# False    35
# dtype: int64

# %%
df.isnull().any()
# Out:
# Id              False
# MSSubClass      False
# MSZoning        False
# LotFrontage     False
# LotArea         False
# Street          False
# LotShape        False
# LandContour     False
# Utilities       False
# LotConfig       False
# LandSlope       False
# Neighborhood    False
# Condition1      False
# Condition2      False
# BldgType        False
# HouseStyle      False
# OverallQual     False
# OverallCond     False
# YearBuilt       False
# YearRemodAdd    False
# RoofStyle       False
# RoofMatl        False
# Exterior1st     False
# Exterior2nd     False
# MasVnrType      False
# MasVnrArea      False
# ExterQual       False
# ExterCond       False
# Foundation      False
# BsmtQual        False
# BsmtCond        False
# BsmtExposure    False
# BsmtFinType1    False
# BsmtFinSF1      False
# BsmtFinType2    False
# dtype: bool

# %%
df.to_csv('Final_dataset.csv')
